# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime as dt
import matplotlib
df = pd.read_csv('/Users/runi/Downloads/ny_data.csv', index_col = 0)
df['date'] = pd.to_datetime(df['date'])
df_temp = df.set_index('date')
df_temp['avgTemp'].plot()
plt.plot(df_temp['avgTemp'])
plt.show()

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.7.1'

# %%
df = pd.read_csv('/Users/runi/Downloads/ny_data.csv', index_col = 0)

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'avgTemp', '_merge'],
#       dtype='object')

# %%
df.drop(columns = {'_merge'}, inplace = True)

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  3255D3E3F33CDC45   classic_bike  2022-03-18 15:38:17  2022-03-18 15:45:34
# 1  17FA5604A37338F9  electric_bike  2022-03-04 16:44:48  2022-03-04 16:50:45
# 2  7DEC9ADDB8D6BBE1  electric_bike  2022-03-13 17:44:32  2022-03-13 17:54:44
# 3  9D69F74EEF231A2E   classic_bike  2022-03-13 15:33:47  2022-03-13 15:41:22
# 4  C84AE4A9D78A6347   classic_bike  2022-03-11 12:21:18  2022-03-11 12:33:24
#
#                        start_station_name start_station_id  \
# 0  Mama Johnson Field - 4 St & Jackson St            HB404
# 1                   Baldwin at Montgomery            JC020
# 2                   Baldwin at Montgomery            JC020
# 3                   Baldwin at Montgomery            JC020
# 4                   Baldwin at Montgomery            JC020
#
#                                end_station_name end_station_id  start_lat  \
# 0  South Waterfront Walkway - Sinatra Dr & 1 St          HB103  40.743140
# 1                                 Grove St PATH          JC005  40.723659
# 2                                 Grove St PATH          JC005  40.723659
# 3                                 Grove St PATH          JC005  40.723659
# 4                                 Grove St PATH          JC005  40.723659
#
#    start_lng    end_lat    end_lng member_casual        date  avgTemp
# 0 -74.040041  40.736982 -74.027781        casual  2022-03-18     13.9
# 1 -74.064194  40.719586 -74.043117        member  2022-03-04     -1.9
# 2 -74.064194  40.719586 -74.043117        member  2022-03-13     -2.3
# 3 -74.064194  40.719586 -74.043117        member  2022-03-13     -2.3
# 4 -74.064194  40.719586 -74.043117        member  2022-03-11      7.2

# %%
df.tail()
# Out:
#                  ride_id  rideable_type           started_at  \
# 895480  D438F1622839AC50   classic_bike  2022-12-06 15:43:38
# 895481  747A63A8E782D171  electric_bike  2022-12-08 08:17:51
# 895482  AE090858CFDE6E82  electric_bike  2022-12-23 14:10:07
# 895483  B3CC8E70AF4E259C   classic_bike  2022-12-02 04:43:25
# 895484  176B601F21327350   classic_bike  2022-12-30 14:50:17
#
#                    ended_at                      start_station_name  \
# 895480  2022-12-06 15:53:57                                  Dey St
# 895481  2022-12-08 08:23:33           9 St HBLR - Jackson St & 8 St
# 895482  2022-12-23 14:14:18  Mama Johnson Field - 4 St & Jackson St
# 895483  2022-12-02 04:46:55  Mama Johnson Field - 4 St & Jackson St
# 895484  2022-12-30 14:55:37       14 St Ferry - 14 St & Shipyard Ln
#
#        start_station_id                  end_station_name end_station_id  \
# 895480            JC065                    Riverview Park          JC057
# 895481            HB305  City Hall - Washington St & 1 St          HB105
# 895482            HB404  City Hall - Washington St & 1 St          HB105
# 895483            HB404  City Hall - Washington St & 1 St          HB105
# 895484            HB202  City Hall - Washington St & 1 St          HB105
#
#         start_lat  start_lng    end_lat    end_lng member_casual        date  \
# 895480  40.737828 -74.067083  40.744319 -74.043991        member  2022-12-06
# 895481  40.747907 -74.038412  40.737360 -74.030970        casual  2022-12-08
# 895482  40.743140 -74.040041  40.737360 -74.030970        member  2022-12-23
# 895483  40.743135 -74.040080  40.737360 -74.030970        member  2022-12-02
# 895484  40.752747 -74.024035  40.737360 -74.030970        member  2022-12-30
#
#         avgTemp
# 895480      9.3
# 895481     11.6
# 895482      7.5
# 895483      3.4
# 895484      9.3

# %%
df.shape
# Out:
# (895485, 15)

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# date                   object
# avgTemp               float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at                    object
# ended_at                      object
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# date                  datetime64[ns]
# avgTemp                      float64
# dtype: object

# %%
df_temp = df.set_index('date')

# %%
df_temp.head()
# Out:
#                      ride_id  rideable_type           started_at  \
# date
# 2022-03-18  3255D3E3F33CDC45   classic_bike  2022-03-18 15:38:17
# 2022-03-04  17FA5604A37338F9  electric_bike  2022-03-04 16:44:48
# 2022-03-13  7DEC9ADDB8D6BBE1  electric_bike  2022-03-13 17:44:32
# 2022-03-13  9D69F74EEF231A2E   classic_bike  2022-03-13 15:33:47
# 2022-03-11  C84AE4A9D78A6347   classic_bike  2022-03-11 12:21:18
#
#                        ended_at                      start_station_name  \
# date
# 2022-03-18  2022-03-18 15:45:34  Mama Johnson Field - 4 St & Jackson St
# 2022-03-04  2022-03-04 16:50:45                   Baldwin at Montgomery
# 2022-03-13  2022-03-13 17:54:44                   Baldwin at Montgomery
# 2022-03-13  2022-03-13 15:41:22                   Baldwin at Montgomery
# 2022-03-11  2022-03-11 12:33:24                   Baldwin at Montgomery
#
#            start_station_id                              end_station_name  \
# date
# 2022-03-18            HB404  South Waterfront Walkway - Sinatra Dr & 1 St
# 2022-03-04            JC020                                 Grove St PATH
# 2022-03-13            JC020                                 Grove St PATH
# 2022-03-13            JC020                                 Grove St PATH
# 2022-03-11            JC020                                 Grove St PATH
#
#            end_station_id  start_lat  start_lng    end_lat    end_lng  \
# date
# 2022-03-18          HB103  40.743140 -74.040041  40.736982 -74.027781
# 2022-03-04          JC005  40.723659 -74.064194  40.719586 -74.043117
# 2022-03-13          JC005  40.723659 -74.064194  40.719586 -74.043117
# 2022-03-13          JC005  40.723659 -74.064194  40.719586 -74.043117
# 2022-03-11          JC005  40.723659 -74.064194  40.719586 -74.043117
#
#            member_casual  avgTemp
# date
# 2022-03-18        casual     13.9
# 2022-03-04        member     -1.9
# 2022-03-13        member     -2.3
# 2022-03-13        member     -2.3
# 2022-03-11        member      7.2

# %%
df_temp['avgTemp'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
plt.plot(df_temp['avgTemp'])
plt.show()

# %%
# Set date as index for time series visualization
df.set_index('date', inplace=True)

# Plot temperatures over time
df['avgTemp'].plot(figsize=(12, 6), title="Daily Average Temperature in 2022", ylabel="Temperature (°C)", xlabel="Date", color="blue")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Set date as index for time series visualization
# ----> 2 df.set_index('date', inplace=True)
#       4 # Plot temperatures over time
#       5 df['avgTemp'].plot(figsize=(12, 6), title="Daily Average Temperature in 2022", ylabel="Temperature (°C)", xlabel="Date", color="blue")
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the processed dataset (final dataset from part 2, step 8)
df = pd.read_csv("processed_data.csv")

# Convert 'date' column to datetime format
df['date'] = pd.to_datetime(df['date'])

# Preview the dataset
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  3255D3E3F33CDC45   classic_bike  2022-03-18 15:38:17  2022-03-18 15:45:34
# 1  17FA5604A37338F9  electric_bike  2022-03-04 16:44:48  2022-03-04 16:50:45
# 2  7DEC9ADDB8D6BBE1  electric_bike  2022-03-13 17:44:32  2022-03-13 17:54:44
# 3  9D69F74EEF231A2E   classic_bike  2022-03-13 15:33:47  2022-03-13 15:41:22
# 4  C84AE4A9D78A6347   classic_bike  2022-03-11 12:21:18  2022-03-11 12:33:24
#
#                        start_station_name start_station_id  \
# 0  Mama Johnson Field - 4 St & Jackson St            HB404
# 1                   Baldwin at Montgomery            JC020
# 2                   Baldwin at Montgomery            JC020
# 3                   Baldwin at Montgomery            JC020
# 4                   Baldwin at Montgomery            JC020
#
#                                end_station_name end_station_id  start_lat  \
# 0  South Waterfront Walkway - Sinatra Dr & 1 St          HB103  40.743140
# 1                                 Grove St PATH          JC005  40.723659
# 2                                 Grove St PATH          JC005  40.723659
# 3                                 Grove St PATH          JC005  40.723659
# 4                                 Grove St PATH          JC005  40.723659
#
#    start_lng    end_lat    end_lng member_casual       date  avgTemp
# 0 -74.040041  40.736982 -74.027781        casual 2022-03-18     13.9
# 1 -74.064194  40.719586 -74.043117        member 2022-03-04     -1.9
# 2 -74.064194  40.719586 -74.043117        member 2022-03-13     -2.3
# 3 -74.064194  40.719586 -74.043117        member 2022-03-13     -2.3
# 4 -74.064194  40.719586 -74.043117        member 2022-03-11      7.2

# %%
# Set date as index for time series visualization
df.set_index('date', inplace=True)

# Plot temperatures over time
df['avgTemp'].plot(figsize=(12, 6), title="Daily Average Temperature in 2022", ylabel="Temperature (°C)", xlabel="Date", color="blue")

# Show plot
plt.show()

# %%
# Count trips per day
trip_counts = df.groupby('date').size().reset_index(name='trip_count')

# Merge trip count data with temperature data
df_merged = df.merge(trip_counts, on='date', how='left')

# Preview merged dataframe
df_merged.head()
# Out:
#         date           ride_id  rideable_type           started_at  \
# 0 2022-03-18  3255D3E3F33CDC45   classic_bike  2022-03-18 15:38:17
# 1 2022-03-04  17FA5604A37338F9  electric_bike  2022-03-04 16:44:48
# 2 2022-03-13  7DEC9ADDB8D6BBE1  electric_bike  2022-03-13 17:44:32
# 3 2022-03-13  9D69F74EEF231A2E   classic_bike  2022-03-13 15:33:47
# 4 2022-03-11  C84AE4A9D78A6347   classic_bike  2022-03-11 12:21:18
#
#               ended_at                      start_station_name  \
# 0  2022-03-18 15:45:34  Mama Johnson Field - 4 St & Jackson St
# 1  2022-03-04 16:50:45                   Baldwin at Montgomery
# 2  2022-03-13 17:54:44                   Baldwin at Montgomery
# 3  2022-03-13 15:41:22                   Baldwin at Montgomery
# 4  2022-03-11 12:33:24                   Baldwin at Montgomery
#
#   start_station_id                              end_station_name  \
# 0            HB404  South Waterfront Walkway - Sinatra Dr & 1 St
# 1            JC020                                 Grove St PATH
# 2            JC020                                 Grove St PATH
# 3            JC020                                 Grove St PATH
# 4            JC020                                 Grove St PATH
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual  \
# 0          HB103  40.743140 -74.040041  40.736982 -74.027781        casual
# 1          JC005  40.723659 -74.064194  40.719586 -74.043117        member
# 2          JC005  40.723659 -74.064194  40.719586 -74.043117        member
# 3          JC005  40.723659 -74.064194  40.719586 -74.043117        member
# 4          JC005  40.723659 -74.064194  40.719586 -74.043117        member
#
#    avgTemp  trip_count
# 0     13.9        2728
# 1     -1.9        1465
# 2     -2.3         781
# 3     -2.3         781
# 4      7.2        1960

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))

# First y-axis for temperature
ax1.set_xlabel("Date")
ax1.set_ylabel("Temperature (°C)", color="blue")
ax1.plot(df_merged.index, df_merged["avgTemp"], color="blue", label="Temperature")
ax1.tick_params(axis="y", labelcolor="blue")

# Second y-axis for bike trips
ax2 = ax1.twinx()
ax2.set_ylabel("Number of Trips", color="red")
ax2.plot(df_merged.index, df_merged["trip_count"], color="red", label="Bike Trips")
ax2.tick_params(axis="y", labelcolor="red")

# Title and Grid
plt.title("Daily Bike Trips & Temperature (2022)")
fig.tight_layout()
plt.show()

# %% [markdown]
# In this code, I used Matplotlib to create a dual-axis line chart. The first y-axis (ax1) represents temperature, while the second y-axis (ax2) represents bike trips. By using twinx(), I was able to overlay two different scales on the same x-axis (date). The blue line represents temperature trends, and the red line represents the number of bike trips per day. This visualization helps identify correlations between temperature and bike usage over time.

# %%
import matplotlib.pyplot as plt

df = pd.read_csv("processed_data.csv")

# Create the figure and axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot bike rides on the primary y-axis
ax1.plot(df_temp['date'], df_temp['_merge'], color='red', label='Daily Bike Rides')
ax1.set_xlabel("Date")
ax1.set_ylabel("Bike Rides", color='red')
ax1.tick_params(axis='y', labelcolor='red')

# Create a secondary y-axis for temperature
ax2 = ax1.twinx()
ax2.plot(df_temp['date'], df_temp['avgTemp'], color='blue', label='Average Temperature')
ax2.set_ylabel("Temperature (°C)", color='blue')
ax2.tick_params(axis='y', labelcolor='blue')

# Add title and legend
plt.title("Bike Trips vs. Temperature Over Time")
fig.legend(loc="upper left", bbox_to_anchor=(0.1,0.9))

# Show the plot
plt.show()

# %%
print(df_temp.columns)
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'avgTemp', '_merge'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Sort data by date to avoid messy lines
df_temp = df_temp.sort_values(by='date')

# Create figure and axis
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot bike rides on the primary y-axis (red line)
ax1.plot(df_temp['date'], df_temp['_merge'], color='red', label='Daily Bike Rides', alpha=0.6)
ax1.set_xlabel("Date")
ax1.set_ylabel("Bike Rides", color='red')

# Create second y-axis for temperature
ax2 = ax1.twinx()
ax2.plot(df_temp['date'], df_temp['avgTemp'], color='blue', label='Average Temperature', marker='o', linestyle='-', alpha=0.6)
ax2.set_ylabel("Temperature (°C)", color='blue')

# Improve legend and grid
fig.legend(loc="upper left")
ax1.grid(True, linestyle="--", alpha=0.5)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.title("Bike Trips vs. Temperature Over Time")
plt.show()

# %%
# Count trips per day
trip_counts = df.groupby('date').size().reset_index(name='trip_count')

# Merge trip count data with temperature data
df_merged = df.merge(trip_counts, on='date', how='left')

# Preview merged dataframe
df_merged.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  3255D3E3F33CDC45   classic_bike  2022-03-18 15:38:17  2022-03-18 15:45:34
# 1  17FA5604A37338F9  electric_bike  2022-03-04 16:44:48  2022-03-04 16:50:45
# 2  7DEC9ADDB8D6BBE1  electric_bike  2022-03-13 17:44:32  2022-03-13 17:54:44
# 3  9D69F74EEF231A2E   classic_bike  2022-03-13 15:33:47  2022-03-13 15:41:22
# 4  C84AE4A9D78A6347   classic_bike  2022-03-11 12:21:18  2022-03-11 12:33:24
#
#                        start_station_name start_station_id  \
# 0  Mama Johnson Field - 4 St & Jackson St            HB404
# 1                   Baldwin at Montgomery            JC020
# 2                   Baldwin at Montgomery            JC020
# 3                   Baldwin at Montgomery            JC020
# 4                   Baldwin at Montgomery            JC020
#
#                                end_station_name end_station_id  start_lat  \
# 0  South Waterfront Walkway - Sinatra Dr & 1 St          HB103  40.743140
# 1                                 Grove St PATH          JC005  40.723659
# 2                                 Grove St PATH          JC005  40.723659
# 3                                 Grove St PATH          JC005  40.723659
# 4                                 Grove St PATH          JC005  40.723659
#
#    start_lng    end_lat    end_lng member_casual        date  avgTemp  \
# 0 -74.040041  40.736982 -74.027781        casual  2022-03-18     13.9
# 1 -74.064194  40.719586 -74.043117        member  2022-03-04     -1.9
# 2 -74.064194  40.719586 -74.043117        member  2022-03-13     -2.3
# 3 -74.064194  40.719586 -74.043117        member  2022-03-13     -2.3
# 4 -74.064194  40.719586 -74.043117        member  2022-03-11      7.2
#
#    trip_count
# 0        2728
# 1        1465
# 2         781
# 3         781
# 4        1960

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("processed_data.csv")

df_temp = df_temp.sort_values(by='date')

# Create figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot bike rides on the primary y-axis (red line)
ax1.plot(df_temp['date'], df_merged["trip_count"], color='red', label='Daily Bike Rides', linestyle='-', alpha=0.6)
ax1.set_xlabel("Date")
ax1.set_ylabel("Bike Rides", color='red')

#df_temp['date'], df_merged["trip_count"], color='red', label='Daily Bike Rides', alpha=0.6

# Second y-axis for bike trips
#ax2.set_ylabel("Number of Trips", color="red")
#ax2.plot(df_merged.index, df_merged["trip_count"], color="red", label="Bike Trips")
#ax2.tick_params(axis="y", labelcolor="red")
#df_merged.index

# Create second y-axis for temperature
ax2 = ax1.twinx()
ax2.plot(df_temp['date'], df_temp['avgTemp'], color='blue', label='Average Temperature', linestyle='-', alpha=0.6)
ax2.set_ylabel("Temperature (°C)", color='blue')

#marker='o'

# Improve legend and grid
fig.legend(loc="upper left")
ax1.grid(True, linestyle="--", alpha=0.5)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.title("Bike Trips vs. Temperature Over Time")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 import matplotlib.pyplot as plt
#       2 import pandas as pd
# ----> 4 df = pd.read_csv("processed_data.csv")
#       6 df_temp = df_temp.sort_values(by='date')
#       8 # Create figure and axis
#
# File /opt/anaconda3/envs/citibike_env/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/citibike_env/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/envs/citibike_env/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File /opt/anaconda3/envs/citibike_env/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda3/envs/citibike_env/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File /opt/anaconda3/envs/citibike_env/lib/python3.9/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'processed_data.csv'

# %% [markdown]
# import matplotlib.pyplot as plt
# import pandas as pd
#
# df = pd.read_csv("/Users/runi/Downloads/processed_data.csv")
#
# df_temp = df_temp.sort_values(by='date')
#
# # Create figure and axis
# fig, ax1 = plt.subplots(figsize=(20, 8))
#
# # Plot bike rides on the primary y-axis (red line)
# ax1.plot(df_temp['date'], df_merged["trip_count"], color='red', label='Daily Bike Rides', linestyle=':', alpha=0.9)
# ax1.set_xlabel("Date")
# ax1.set_ylabel("Bike Rides", color='red')
#
# #'-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'
# #df_temp['date'], df_merged["trip_count"], color='red', label='Daily Bike Rides', alpha=0.6
#
# # Second y-axis for bike trips
# #ax2.set_ylabel("Number of Trips", color="red")
# #ax2.plot(df_merged.index, df_merged["trip_count"], color="red", label="Bike Trips")
# #ax2.tick_params(axis="y", labelcolor="red")
# #df_merged.index
#
# # Create second y-axis for temperature
# ax2 = ax1.twinx()
# ax2.plot(df_temp['date'], df_temp['avgTemp'], color='blue', label='Average Temperature', linestyle='-', linewidth=2, alpha=0.6)
# ax2.set_ylabel("Temperature (°C)", color='blue')
#
# #marker='o'
#
# # Improve legend and grid
# fig.legend(loc="upper left")
# ax1.grid(True, linestyle="--", alpha=0.5)
#
# # Rotate x-axis labels for better readability
# plt.xticks(rotation=45)
#
# # Show the plot
# plt.title("Bike Trips vs. Temperature Over Time")
# plt.show()

# %%
#import pandas as pd

##df = pd.read_csv('/Users/runi/Downloads/ny_data.csv', index_col = 0)

#df['date'] = pd.to_datetime(df['started_at']).dt.date

#trip_counts = df.groupby('date').size().reset_index(name='trip_count')

#weather_df['date'] = pd.to_datetime(weather_df['date']).dt.date  

#df_daily = pd.merge(weather_df, trip_counts, on='date', how='left')

#df_final = pd.merge(df, df_daily[['date', 'avgTemp', 'trip_count']], on='date', how='left')

#df_final.head()

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime as dt
import matplotlib
df = pd.read_csv('/Users/runi/Downloads/ny_data.csv', index_col = 0)
df['date'] = pd.to_datetime(df['date'])
df_temp = df.set_index('date')
df_temp['avgTemp'].plot()
# Set date as index for time series visualization
df.set_index('date', inplace=True)

# Plot temperatures over time
df['avgTemp'].plot(figsize=(12, 6), title="Daily Average Temperature in 2022", ylabel="Temperature (°C)", xlabel="Date", color="blue")

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the processed dataset (final dataset from part 2, step 8)
df = pd.read_csv("/Users/runi/Downloads/processed_data.csv")

# Convert 'date' column to datetime format
df['date'] = pd.to_datetime(df['date'])

# Preview the dataset
df.head()


# Count trips per day
trip_counts = df.groupby('date').size().reset_index(name='trip_count')

# Merge trip count data with temperature data
df_merged = df.merge(trip_counts, on='date', how='left')

# Preview merged dataframe
df_merged.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  3255D3E3F33CDC45   classic_bike  2022-03-18 15:38:17  2022-03-18 15:45:34
# 1  17FA5604A37338F9  electric_bike  2022-03-04 16:44:48  2022-03-04 16:50:45
# 2  7DEC9ADDB8D6BBE1  electric_bike  2022-03-13 17:44:32  2022-03-13 17:54:44
# 3  9D69F74EEF231A2E   classic_bike  2022-03-13 15:33:47  2022-03-13 15:41:22
# 4  C84AE4A9D78A6347   classic_bike  2022-03-11 12:21:18  2022-03-11 12:33:24
#
#                        start_station_name start_station_id  \
# 0  Mama Johnson Field - 4 St & Jackson St            HB404
# 1                   Baldwin at Montgomery            JC020
# 2                   Baldwin at Montgomery            JC020
# 3                   Baldwin at Montgomery            JC020
# 4                   Baldwin at Montgomery            JC020
#
#                                end_station_name end_station_id  start_lat  \
# 0  South Waterfront Walkway - Sinatra Dr & 1 St          HB103  40.743140
# 1                                 Grove St PATH          JC005  40.723659
# 2                                 Grove St PATH          JC005  40.723659
# 3                                 Grove St PATH          JC005  40.723659
# 4                                 Grove St PATH          JC005  40.723659
#
#    start_lng    end_lat    end_lng member_casual       date  avgTemp  \
# 0 -74.040041  40.736982 -74.027781        casual 2022-03-18     13.9
# 1 -74.064194  40.719586 -74.043117        member 2022-03-04     -1.9
# 2 -74.064194  40.719586 -74.043117        member 2022-03-13     -2.3
# 3 -74.064194  40.719586 -74.043117        member 2022-03-13     -2.3
# 4 -74.064194  40.719586 -74.043117        member 2022-03-11      7.2
#
#    trip_count
# 0        2728
# 1        1465
# 2         781
# 3         781
# 4        1960

# %%
df_temp = df_temp.sort_values(by='date')

fig, ax1 = plt.subplots(figsize=(12, 6))

#df_merged["date"]
#df_merged.index

# First y-axis for temperature
ax1.set_xlabel("Date")
ax1.set_ylabel("Temperature (°C)", color="blue")
ax1.plot(df_merged["date"], df_merged["avgTemp"], color="blue", label="Temperature", linestyle='-', alpha=0.8)
ax1.tick_params(axis="y", labelcolor="blue")

# Create second y-axis for temperature
#ax2 = ax1.twinx()
##ax2.plot(df_temp['date'], df_temp['avgTemp'], color='blue', label='Average Temperature', marker='o', linestyle='-', alpha=0.6)
#ax2.set_ylabel("Temperature (°C)", color='blue')

# Second y-axis for bike trips
ax2 = ax1.twinx()
ax2.set_ylabel("Number of Trips", color="red")
ax2.plot(df_merged["date"], df_merged["trip_count"], color="red", label="Bike Trips", linestyle='-', alpha=0.6)
ax2.tick_params(axis="y", labelcolor="red")

###########
# Plot bike rides on the primary y-axis (red line)
##ax1.plot(df_temp['date'], df_temp['_merge'], color='red', label='Daily Bike Rides', alpha=0.6)
#ax1.set_xlabel("Date")
#ax1.set_ylabel("Bike Rides", color='red')
###########

# Title and Grid
plt.title("Daily Bike Trips & Temperature (2022)")
fig.tight_layout()
plt.show()




##import matplotlib.pyplot as plt

# Sort data by date to avoid messy lines
#df_temp = df_temp.sort_values(by='date')



# Improve legend and grid
fig.legend(loc="upper left")
ax1.grid(True, linestyle="--", alpha=0.5)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)



#
# Count trips per day
#trip_counts = df.groupby('date').size().reset_index(name='trip_count')

# Merge trip count data with temperature data
#df_merged = df.merge(trip_counts, on='date', how='left')

# Preview merged dataframe
#df_merged.head()

# %%
df_temp.head()
# Out:
#                      ride_id  rideable_type           started_at  \
# date
# 2022-01-01  B42E6C17AF007611   classic_bike  2022-01-01 00:19:27
# 2022-01-01  D5C9BBDBC66CEBF6   classic_bike  2022-01-01 13:48:18
# 2022-01-01  F7D69E45F52F0ECA  electric_bike  2022-01-01 07:29:44
# 2022-01-01  56E148D263A0B8F2   classic_bike  2022-01-01 01:03:38
# 2022-01-01  2F3A132B6C4F781D  electric_bike  2022-01-01 18:33:00
#
#                        ended_at                            start_station_name  \
# date
# 2022-01-01  2022-01-01 00:25:03       Hoboken Terminal - River St & Hudson Pl
# 2022-01-01  2022-01-01 13:57:13             14 St Ferry - 14 St & Shipyard Ln
# 2022-01-01  2022-01-02 00:34:32  South Waterfront Walkway - Sinatra Dr & 1 St
# 2022-01-01  2022-01-01 01:20:05                                Columbus Drive
# 2022-01-01  2022-01-01 18:51:41                               Adams St & 2 St
#
#            start_station_id                         end_station_name  \
# date
# 2022-01-01            HB102                          Adams St & 2 St
# 2022-01-01            HB202  Hoboken Terminal - River St & Hudson Pl
# 2022-01-01            HB103                          Brunswick & 6th
# 2022-01-01            JC014                                  Hilltop
# 2022-01-01            HB407  Hoboken Terminal - River St & Hudson Pl
#
#            end_station_id  start_lat  start_lng    end_lat    end_lng  \
# date
# 2022-01-01          HB407  40.736068 -74.029127  40.739814 -74.036904
# 2022-01-01          HB102  40.752961 -74.024353  40.736068 -74.029127
# 2022-01-01          JC081  40.736982 -74.027781  40.726012 -74.050389
# 2022-01-01          JC019  40.718355 -74.038914  40.731169 -74.057574
# 2022-01-01          HB102  40.739814 -74.036904  40.736068 -74.029127
#
#            member_casual  avgTemp _merge
# date
# 2022-01-01        member     11.6   both
# 2022-01-01        member     11.6   both
# 2022-01-01        casual     11.6   both
# 2022-01-01        casual     11.6   both
# 2022-01-01        member     11.6   both

# %%
df_merged.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  3255D3E3F33CDC45   classic_bike  2022-03-18 15:38:17  2022-03-18 15:45:34
# 1  17FA5604A37338F9  electric_bike  2022-03-04 16:44:48  2022-03-04 16:50:45
# 2  7DEC9ADDB8D6BBE1  electric_bike  2022-03-13 17:44:32  2022-03-13 17:54:44
# 3  9D69F74EEF231A2E   classic_bike  2022-03-13 15:33:47  2022-03-13 15:41:22
# 4  C84AE4A9D78A6347   classic_bike  2022-03-11 12:21:18  2022-03-11 12:33:24
#
#                        start_station_name start_station_id  \
# 0  Mama Johnson Field - 4 St & Jackson St            HB404
# 1                   Baldwin at Montgomery            JC020
# 2                   Baldwin at Montgomery            JC020
# 3                   Baldwin at Montgomery            JC020
# 4                   Baldwin at Montgomery            JC020
#
#                                end_station_name end_station_id  start_lat  \
# 0  South Waterfront Walkway - Sinatra Dr & 1 St          HB103  40.743140
# 1                                 Grove St PATH          JC005  40.723659
# 2                                 Grove St PATH          JC005  40.723659
# 3                                 Grove St PATH          JC005  40.723659
# 4                                 Grove St PATH          JC005  40.723659
#
#    start_lng    end_lat    end_lng member_casual       date  avgTemp  \
# 0 -74.040041  40.736982 -74.027781        casual 2022-03-18     13.9
# 1 -74.064194  40.719586 -74.043117        member 2022-03-04     -1.9
# 2 -74.064194  40.719586 -74.043117        member 2022-03-13     -2.3
# 3 -74.064194  40.719586 -74.043117        member 2022-03-13     -2.3
# 4 -74.064194  40.719586 -74.043117        member 2022-03-11      7.2
#
#    trip_count
# 0        2728
# 1        1465
# 2         781
# 3         781
# 4        1960

# %%
df_temp = df_temp.sort_values(by='date')
df_merged = df_merged.sort_values(by='date')

# %%
df_temp = df_temp.sort_values(by='date')

fig, ax1 = plt.subplots(figsize=(12, 6))

#df_merged["date"]
#df_merged.index

# First y-axis for temperature
ax1.set_xlabel("Date")
ax1.set_ylabel("Temperature (°C)", color="blue")
ax1.plot(df_merged["date"], df_merged["avgTemp"], color="blue", label="Temperature", linestyle='-', alpha=0.8)
ax1.tick_params(axis="y", labelcolor="blue")

# Create second y-axis for temperature
#ax2 = ax1.twinx()
##ax2.plot(df_temp['date'], df_temp['avgTemp'], color='blue', label='Average Temperature', marker='o', linestyle='-', alpha=0.6)
#ax2.set_ylabel("Temperature (°C)", color='blue')

# Second y-axis for bike trips
ax2 = ax1.twinx()
ax2.set_ylabel("Number of Trips", color="red")
ax2.plot(df_merged["date"], df_merged["trip_count"], color="red", label="Bike Trips", linestyle='-', alpha=0.6)
ax2.tick_params(axis="y", labelcolor="red")

###########
# Plot bike rides on the primary y-axis (red line)
##ax1.plot(df_temp['date'], df_temp['_merge'], color='red', label='Daily Bike Rides', alpha=0.6)
#ax1.set_xlabel("Date")
#ax1.set_ylabel("Bike Rides", color='red')
###########

# Title and Grid
plt.title("Daily Bike Trips & Temperature (2022)")
fig.tight_layout()
plt.show()




##import matplotlib.pyplot as plt

# Sort data by date to avoid messy lines
#df_temp = df_temp.sort_values(by='date')



# Improve legend and grid
#fig.legend(loc="upper left")
#ax1.grid(True, linestyle="--", alpha=0.5)

# Rotate x-axis labels for better readability
#plt.xticks(rotation=45)



#
# Count trips per day
#trip_counts = df.groupby('date').size().reset_index(name='trip_count')

# Merge trip count data with temperature data
#df_merged = df.merge(trip_counts, on='date', how='left')

# Preview merged dataframe
#df_merged.head()
